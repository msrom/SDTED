# %% [markdown]
# 3.2.5

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 67
#      65 pos = nx.spring_layout(G, k=1, seed=42)
#      66 plt.figure(figsize=(10,10))
# ---> 67 nx.draw(G, pos, with_labels=True, node_color="#ffca28", node_size=2000, font_size=8)
#      68 edge_labels = nx.get_edge_attributes(G, 'label')
#      69 nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='gray', font_size=6)
#
# File ~/Escritorio/UC3M/Provenance Graph Stuff/Metrics Graph Reconstruction/github/venv/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py:126, in draw(G, pos, ax, **kwds)
#     123     kwds['with_labels'] = 'labels' in kwds
#     125 try:
# --> 126     draw_networkx(G, pos=pos, ax=ax, **kwds)
#     127     ax.set_axis_off()
#     128     plt.draw_if_interactive()
#
# ...
